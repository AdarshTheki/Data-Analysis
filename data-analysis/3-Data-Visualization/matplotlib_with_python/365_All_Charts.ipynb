# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # Bar Charts

# %%
cars = pd.read_csv("1_bar_chart_data.csv")

# %%
plt.figure(figsize = (5,3))
plt.bar (x = cars["Brand"], height = cars["Cars Listings"], color = "lightseagreen")
plt.xticks (rotation = 45, fontsize = 10 )
plt.yticks (fontsize = 10)
plt.xlabel ( "No. of Brands Cars", fontsize = 13, fontweight = "bold" )
plt.ylabel ( "No. of Listings Cars", fontsize = 13, fontweight = "bold" )
plt.title ( "Cars Listings by Brands", fontsize = 18, fontweight = "bold" )
sns.despine()
plt.show()

# %% [markdown]
# # Pie Charts

# %%
fuel = pd.read_csv("2_pie_chart_data.csv")

# %%
plt.figure(figsize=(8,5))
plt.pie ( fuel["Number of Cars"],
          labels = fuel["Engine Fuel Type"].values, 
          autopct = "%.2f%%",
          textprops = {'size' : 'large',
                      'fontweight' : 'bold',
                      'rotation' : '20',
                      'color':'w'} )
plt.legend(fontsize = "x-small", title='Fuel Type')
plt.title ("Cars by Engine Fuel Type", fontsize = 18, fontweight = "bold" )
plt.show()

# %% [markdown]
# # Stacked Area Chart

# %%
Engine = pd.read_csv("3_stacked_area_chart_data.csv")

# %%
from cProfile import label
from turtle import color

colors = ["#011638", "#7e2987", "ef2026"]
label = ["Diesel", "Petrol", "Gas"]
sns.set_style("white")
plt.figure(figsize=(12,3))
plt.stackplot  ( Engine["Year"],
                 Engine["Diesel"],
                 Engine["Petrol"],
                 Engine['Gas'],
                 colors = colors,
                 edgecolor = 'none')
plt.xticks(Engine["Year"], rotation = 45) 
plt.legend(labels = label, loc = "upper left") 
plt.ylabel("Number of Cars", fontsize = 13)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)", fontsize = 14, weight = "bold")
sns.despine() # Remove top and right border of the chart.
plt.show()

# %% [markdown]
# # Line Charts

# %%
line_chart = pd.read_csv("4_line_chart_data.csv")

# %%
line_chart["new_date"] = pd.to_datetime(line_chart["Date"])

# %%
label = ["GSPC500", "FTSE100"]
plt.figure(figsize = (7,2))
plt.plot(line_chart["new_date"], line_chart["GSPC500"])
plt.plot(line_chart["new_date"], line_chart["FTSE100"])
plt.title ( "GSPC v/s FTSE Returns (2000 - 2010)", fontsize = 12, fontweight = "bold" )
plt.ylabel("Returns", fontsize = 12)
plt.xlabel("Date", fontsize = 12)
plt.legend(labels = label, fontsize = "medium")
sns.despine()
plt.show()

# %%
line_chart_2008 = line_chart[(line_chart.new_date >= '2008-07-01') & (line_chart.new_date <= '2008-12-31')]

# %%
plt.figure(figsize = (7,2))
plt.plot(line_chart_2008["new_date"], line_chart_2008["GSPC500"], color = 'midnightblue')
plt.plot(line_chart_2008["new_date"], line_chart_2008["FTSE100"], color = 'crimson')
plt.title ( "GSPC v/s FTSE Returns (High - 2008)", fontsize = 10, fontweight = "bold" )
plt.ylabel("Returns", fontsize = 8)
plt.xlabel("Date", fontsize = 8)
plt.legend(labels = label, fontsize = "small")
sns.despine()
plt.show()

# %% [markdown]
# # Histograms Charts

# %%
histogram = pd.read_csv("5_histogram.csv")

# %%
plt.figure(figsize=(4,3))
plt.hist(histogram["Price"],
        bins=8,
        color="#108A99")
plt.title("Distribution of Real Estate Prices", fontsize = 10, fontweight = "bold" )
plt.xlabel("Price in (000's $)", fontsize = 8)
plt.ylabel("Number of Propertys",  fontsize = 8)
sns.despine()
plt.show()

# %% [markdown]
# # Scatter plot Charts

# %%
real_estate = pd.read_csv("6_scatter_plot.csv")

# %%
from matplotlib.pyplot import title

plt.figure(figsize=(6,4))
scatter = plt.scatter(real_estate["Area (ft.)"],
        real_estate["Price"],
        alpha = 0.6,
        c = real_estate["Building Type"],
        cmap = "viridis")
plt.legend( *scatter.legend_elements(), loc = "lower right", title = "Building Type")
plt.title( "Relationship between Area and Price of California Real Estate", fontsize = 14, fontweight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold")
plt.ylabel("Price (000's of $)", weight = "bold")
sns.despine()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(real_estate["Price"],
                real_estate["Area (ft.)"],
                hue = real_estate["Building Type"],
                palette = ['black', 'darkblue', 'purple', 'pink', 'white'],
                s = 100 )
plt.title( "Relationship between Area and Price of California Real Estate", fontsize = 14, fontweight = "bold")
plt.xlabel("Area (sq. ft.)", weight = "bold")
plt.ylabel("Price (000's of $)", weight = "bold")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Regression Plot Charts

# %%
expenditure = pd.read_csv("7_regression_plot.csv")
# expenditure ( Ad_Budget,  Sales) - two column

# %%
# sns.set(rc = {'figure.figsize': (6,4)}) 
plt.figure(figsize=(5,4))
sns.regplot(x = "Ad_Budget", 
            y = "Sales", 
            data = expenditure, 
            scatter_kws = {'color': 'k'}, 
            line_kws = {'color': 'red'}) 
plt.xlabel("Ad Expenditure in (100's $)")
plt.ylabel("Sales in (5's Units)")
plt.title("Effect of Ad Expenditure on Sales", fontsize = 14, weight = "bold")
sns.despine()
plt.show()

# %%
sns.lmplot(x = "Ad_Budget", 
           y = "Sales", 
           data = expenditure, 
           height = 4,                     # height and width of the plot
           scatter_kws = {'color': 'k'},   # color for the points
           line_kws = {'color': 'red'})    # color for the regression line
plt.xlabel("Ad Expenditure in (000's $)")
plt.ylabel("Sales in (000's Units)")
plt.title("Effect of Ad Expenditure on Sales", fontsize = 14, weight = "bold")
plt.show()

# %% [markdown]
# # Bar Line Charts

# %%
from matplotlib.ticker import PercentFormatter #converts values into percentage format

# %%
df_kdnuggets = pd.read_csv("8_bar_line_chart.csv")

# %%
df_kdnuggets #the data frame, which we'll use to create the combo plot. The two charts will share the x-axis which is Year.
# The bar chart will have the number of Participants on the primary x-axis(on the lefthandside of the chart)
# The line chart will have the Python Users in percentages on a secondary y-axis(on the righthandside of the chart)
# Out:
#    Year  Python Users  Participants
# 0  2012         0.149           798
# 1  2013         0.133          1880
# 2  2014         0.195          3285
# 3  2015         0.303          2800
# 4  2016         0.458          2895
# 5  2017         0.526          2900
# 6  2018         0.656          2300
# 7  2019         0.658          1800

# %%
# Creating the combination chart. Here we use a figure with axes.
# The first axes or subplot is the bar chart, the second is the line chart. 
fig, ax = plt.subplots(figsize = (8, 5))

#creating and styling the bar chart
ax.bar(df_kdnuggets["Year"],
       df_kdnuggets["Participants"],
       color = "k")
ax.set_ylabel("Number of Participants", 
              weight = "bold")
ax.tick_params(axis = "y", 
               width = 2, 
               labelsize = "large")
ax1 = ax.twinx()
#changing the secondary y-axis to display percentages on a scale from 0% to 100%
ax1.set_ylim(0, 1)
ax1.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))
#creating and styling the line chart
ax1.plot(df_kdnuggets["Year"],
         df_kdnuggets["Python Users"], 
         color = "#b60000", 
         marker = "D")
ax1.set_ylabel("Python Users", 
               color = "#b60000", 
               weight = "bold")
ax1.tick_params(axis = "y", 
                colors = "#b60000", 
                width = 2, 
                labelsize = "large")
ax.set_title("KD Nuggets Survey Python Users (2012 - 2019)", fontsize = "14", weight = "bold")
plt.show()
